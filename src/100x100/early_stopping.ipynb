# %% [markdown]
# # Environment preparation

# %%
# !pip install tensorflow scikit-learn matplotlib numpy

# %%
import tensorflow as tf

print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
sess = tf.compat.v1.Session(config=tf.compat.v1.ConfigProto(log_device_placement=True))
# Out:
# Num GPUs Available:  1
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:00:04.0, compute capability: 8.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from tensorflow.keras import mixed_precision

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)

    # Enable mixed precision
    mixed_precision.set_global_policy('mixed_float16')
  except RuntimeError as e:
    print(e)
else:
  print('No GPU found')

# %% [markdown]
# # Data loading

# %%
import tensorflow as tf

image_side_size = 100
image_size = (image_side_size, image_side_size)
batch_size = 128
base_path = f'/content/drive/My Drive/Lucas/TCC/data/segmented_images/{image_side_size}x{image_side_size}'
#base_path = '/content/drive/My Drive/Personal/MBA/data/segmented_images/'

# Load the dataset
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    base_path,
    image_size=image_size,  # Resize images to 100x100 pixels
    batch_size=batch_size,  # Adjust the batch size as needed
    label_mode='categorical',  # Use 'categorical' for multi-class classification
    shuffle=True,  # Shuffle data to ensure randomness
    validation_split=0.2,  # Use 20% of the data for validation
    subset="training",  # This is the training subset
    seed=123  # Fix seed to ensure consistent shuffling
)

# Load the validation set as well
val_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    base_path,
    image_size=image_size,
    batch_size=batch_size,
    label_mode='categorical',
    shuffle=True,
    validation_split=0.2,
    subset="validation",  # This is the validation subset
    seed=123
)

# Check the class names
print(f"Class names: {dataset.class_names}")
# Out:
# Found 11109 files belonging to 6 classes.
# Using 8888 files for training.
# Found 11109 files belonging to 6 classes.
# Using 2221 files for validation.
# Class names: ['asch', 'ascus', 'hsil', 'lsil', 'normal', 'scc']

# %%
# Print data distribution
import numpy as np
import matplotlib.pyplot as plt

# Initialize a dictionary to store the class counts
class_counts = {class_name: 0 for class_name in dataset.class_names}

# Iterate through the dataset to count occurrences of each class
for images, labels in dataset:
    labels = np.argmax(labels.numpy(), axis=1)  # Convert one-hot encoded labels to class indices
    for label in labels:
        class_name = dataset.class_names[label]
        class_counts[class_name] += 1

# Print class counts
print("Class distribution in the training dataset:")
for class_name, count in class_counts.items():
    print(f"{class_name}: {count}")

# Plot a bar chart of the class distribution
plt.bar(class_counts.keys(), class_counts.values())
plt.xlabel('Classes')
plt.ylabel('Number of Images')
plt.title('Class Distribution')
plt.xticks(rotation=45)
plt.show()
# Out:
# Class distribution in the training dataset:
# asch: 747
# ascus: 480
# hsil: 1335
# lsil: 1070
# normal: 5127
# scc: 129

# %% [markdown]
# ## Augmentation

# %%
import tensorflow as tf

# List of minority classes (asch, ascus, scc)
minority_classes = ['asch', 'ascus', 'scc']
minority_class_indices = [dataset.class_names.index(cls) for cls in minority_classes]

# Unbatch the dataset to process individual images
unbatched_dataset = dataset.unbatch()

# Function to check if the label belongs to one of the minority classes
def is_minority_class(image, label):
    # Check if the label belongs to the minority classes
    return tf.reduce_any(tf.math.equal(tf.argmax(label, axis=-1), minority_class_indices))

# Filter to keep only the minority classes
minority_dataset = unbatched_dataset.filter(is_minority_class)

# Define augmentation function for a single image
def augment_single_image(image):
    # Apply random rotations (90º, 180º, 270º)
    image = tf.image.rot90(image, k=tf.random.uniform(shape=[], minval=0, maxval=4, dtype=tf.int32))

    # Apply random horizontal and vertical flips
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)

    # Apply zoom by scaling and resizing (alternative to random_crop)
    scaling_factor = tf.random.uniform([], minval=0.8, maxval=1.2, dtype=tf.float32)
    new_size = tf.cast(scaling_factor * 100, tf.int32)

    # Resize the image by scaling factor and then resize back to original size
    image = tf.image.resize(image, [new_size, new_size])
    image = tf.image.resize_with_crop_or_pad(image, 100, 100)  # Ensure the size remains 100x100

    return image

# Apply augmentation to the minority class dataset
augmented_minority_dataset = minority_dataset.map(lambda image, label: (augment_single_image(image), label))

# Re-batch the dataset after augmentation
augmented_minority_dataset = augmented_minority_dataset.batch(32)

# Concatenate the original and augmented datasets
final_dataset = dataset.concatenate(augmented_minority_dataset)

# Prefetch and shuffle the final dataset
final_dataset = final_dataset.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Initialize a dictionary to store the class counts
class_counts = {class_name: 0 for class_name in dataset.class_names}

# Iterate through the final_dataset to count occurrences of each class
for images, labels in final_dataset:
    labels = np.argmax(labels.numpy(), axis=1)  # Convert one-hot encoded labels to class indices
    for label in labels:
        class_name = dataset.class_names[label]
        class_counts[class_name] += 1

# Print class counts
print("Class distribution in the final dataset (after augmentation):")
for class_name, count in class_counts.items():
    print(f"{class_name}: {count}")

# Plot a bar chart of the class distribution
plt.bar(class_counts.keys(), class_counts.values())
plt.xlabel('Classes')
plt.ylabel('Number of Images')
plt.title('Class Distribution After Augmentation')
plt.xticks(rotation=45)
plt.show()
# Out:
# Class distribution in the final dataset (after augmentation):
# asch: 1494
# ascus: 960
# hsil: 1335
# lsil: 1070
# normal: 5127
# scc: 258

# %%
class_factor = {
    'asch': (class_counts['normal']/class_counts['asch']) - 1,
    'ascus': (class_counts['normal']/class_counts['ascus']) - 1,
    'hsil': (class_counts['normal']/class_counts['hsil']) - 1,
    'lsil': (class_counts['normal']/class_counts['lsil']) - 1,
    'scc': (class_counts['normal']/class_counts['scc']) - 1
}

class_factor
# Out:
# {'asch': 2.431726907630522,
#  'ascus': 4.340625,
#  'hsil': 2.8404494382022474,
#  'lsil': 3.791588785046729,
#  'scc': 18.872093023255815}

# %%
import tensorflow as tf
import numpy as np

# List of minority classes (asch, ascus, scc)
minority_classes = ['asch', 'ascus', 'hsil', 'lsil', 'scc']
minority_class_indices = [dataset.class_names.index(cls) for cls in minority_classes]

# Unbatch the dataset to process individual images
unbatched_dataset = dataset.unbatch()

# Function to check if the label belongs to one of the minority classes
def is_minority_class(image, label):
    # Check if the label belongs to the minority classes
    return tf.reduce_any(tf.math.equal(tf.argmax(label, axis=-1), minority_class_indices))

# Filter to keep only the minority classes
scc_dataset = unbatched_dataset.filter(is_minority_class)

from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Create an ImageDataGenerator for data augmentation
datagen = ImageDataGenerator(
    rotation_range=20,       # Rotate the image by up to 20 degrees
    width_shift_range=0.2,   # Shift the image horizontally by up to 20%
    height_shift_range=0.2,  # Shift the image vertically by up to 20%
    shear_range=0.2,         # Shear the image by 20%
    zoom_range=0.2,          # Zoom in/out by 20%
    horizontal_flip=True,    # Randomly flip images horizontally
    vertical_flip=True       # Randomly flip images vertically
)

# Generate augmented images for SCC class
# Set a batch size (e.g., 32) and number of augmentations (e.g., augment each image 5 times)
augmented_scc_images = []
augmented_scc_labels = []

for image, label in scc_dataset:
    image = np.expand_dims(image, axis=0)  # Expand dimension for the generator
    i = 0

    class_name = dataset.class_names[label.numpy().argmax()]
    max_aug = class_factor[class_name]

    for batch in datagen.flow(image, batch_size=1):
        augmented_scc_images.append(batch[0])  # Add the augmented image
        augmented_scc_labels.append(dataset.class_names.index(class_name))  # Add the corresponding SCC label
        i += 1
        if i >= max_aug:
            break


# Convert the augmented data to TensorFlow tensors
augmented_scc_images = tf.convert_to_tensor(augmented_scc_images)
augmented_scc_labels = tf.convert_to_tensor(augmented_scc_labels)

# Convert augmented labels to one-hot encoded format
augmented_scc_labels_one_hot = tf.one_hot(augmented_scc_labels, 6)

# Create a dataset from the augmented data
augmented_scc_dataset = tf.data.Dataset.from_tensor_slices((augmented_scc_images, augmented_scc_labels_one_hot))
augmented_scc_dataset = augmented_scc_dataset.batch(batch_size)
# Combine the original dataset with the augmented SCC data
final_dataset = final_dataset.concatenate(augmented_scc_dataset)

# Prefetch and shuffle the final dataset
final_dataset = final_dataset.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Initialize a dictionary to store the class counts
class_counts = {class_name: 0 for class_name in dataset.class_names}

# Iterate through the final_dataset to count occurrences of each class
for images, labels in final_dataset:
    labels = np.argmax(labels.numpy(), axis=1)  # Convert one-hot encoded labels to class indices
    for label in labels:
        class_name = dataset.class_names[label]
        class_counts[class_name] += 1

# Print class counts
print("Class distribution in the final dataset (after augmentation):")
for class_name, count in class_counts.items():
    print(f"{class_name}: {count}")
labels = ['ASC-H', 'ASC-US', 'HSIL', 'LSIL', 'NILM', 'SCC']



# Plot a bar chart of the class distribution
plt.bar(labels, class_counts.values())
plt.xlabel('Classes')
plt.ylabel('Total de células')
plt.title('Distribuição de classes para treinamento')
plt.show()
# Out:
# Class distribution in the final dataset (after augmentation):
# asch: 3735
# ascus: 3360
# hsil: 5340
# lsil: 5350
# normal: 5127
# scc: 2709

# %% [markdown]
# ## Class weights

# %%
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

# Create a list of class labels (these correspond to indices used in training)
class_labels = list(class_counts.keys())
class_indices = np.array([class_labels.index(cls) for cls in class_labels])
class_samples = np.array([class_counts[cls] for cls in class_labels])

# Calculate the class weights
class_weights = compute_class_weight(
    'balanced',
    classes=class_indices,
    y=np.repeat(class_indices, class_samples)
)

# Convert the class weights into a dictionary to pass into the model during training
class_weight_dict = {i: weight for i, weight in enumerate(class_weights)}

# Print the class weights
print("Class weights: ", class_weight_dict)
# Out:
# Class weights:  {0: 1.1432842481035252, 1: 1.2708829365079366, 2: 0.7996566791510612, 3: 0.7981619937694704, 4: 0.8328782263832001, 5: 1.5762889134982159}

# %% [markdown]
# # Training and comparisons

# %%
import tensorflow as tf
from tensorflow.keras.applications import VGG16, ResNet50, EfficientNetB0, InceptionV3, MobileNetV3Small, EfficientNetV2B0
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc, f1_score
import matplotlib.pyplot as plt

# %%
# List of models to compare
model_list = {
    'VGG16': VGG16,
    'ResNet50': ResNet50,
    'EfficientNetB0': EfficientNetB0,
    #'InceptionV3': InceptionV3,
    'MobileNetV3Small': MobileNetV3Small,
    'EfficientNetV2B0': EfficientNetV2B0
}

# Function to build and compile a model
def build_model(model_name, input_shape=(100, 100, 3), num_classes=6):
    base_model = model_list[model_name](weights='imagenet', include_top=False, input_shape=input_shape)
    base_model.trainable = False  # Freeze the base model layers

    model = Sequential([
        base_model,
        Flatten(),
        Dense(256, activation='relu'),
        Dropout(0.5),
        Dense(num_classes, activation='softmax')
    ])

    #InceptionV3 test
    # model.compile(optimizer=tf.keras.optimizers.RMSprop(learning_rate=1e-4),
    #               loss='categorical_crossentropy',
    #               metrics=['accuracy', tf.keras.metrics.Recall(), tf.keras.metrics.Precision()])

    model.compile(optimizer=Adam(),
                  loss='categorical_crossentropy',
                  metrics=['accuracy', tf.keras.metrics.Recall(), tf.keras.metrics.Precision()])

    return model

# %%
# Train each model and store the results
model_results = {}

# Train each model
for model_name in model_list.keys():
    print(f"Training {model_name}...")

    # Build model
    model = build_model(model_name)

    # Callbacks for early stopping and saving the best model
    callbacks = [
        EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True),
        ModelCheckpoint(f'/content/drive/My Drive/Lucas/TCC/{model_name}_best_model_early_stop.keras', monitor='val_loss', save_best_only=True)
    ]

    # Train the model
    history = model.fit(
        final_dataset,
        epochs=100,  # Adjust the number of epochs if necessary
        validation_data=val_dataset,
        class_weight=class_weight_dict,  # Apply class weights
        callbacks=callbacks
    )

    # Evaluate the model
    print(f"Evaluating {model_name} on validation set:")
    val_loss, val_acc, val_recall, val_precision = model.evaluate(val_dataset)

    # Example: Generate confusion matrix and ROC curve for one model (e.g., VGG16)
    print(f'Genearting predictions for {model_name} on validation set:')
    y_true = []  # Store true labels
    y_pred = []  # Store predicted labels
    y_pred_prob = []  # Store predicted probabilities for ROC curve

    # Get predictions from the trained model
    for images, labels in val_dataset:
        preds = model.predict(images)
        y_true.append(np.argmax(labels, axis=1))
        y_pred.append(np.argmax(preds, axis=1))
        y_pred_prob.append(preds)

    # Convert lists to numpy arrays
    y_true = np.concatenate(y_true)
    y_pred = np.concatenate(y_pred)
    y_pred_prob = np.concatenate(y_pred_prob)

    # Save metrics for comparison
    model_results[model_name] = {
        'history': history,
        'model': model,
        'val_loss': val_loss,
        'val_acc': val_acc,
        'val_recall': val_recall,
        'val_precision': val_precision,
        'y_true': y_true,
        'y_pred': y_pred,
        'y_pred_prob': y_pred_prob
    }
# Out:
# Training VGG16...
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# Epoch 1/100
#     228/Unknown 23s 63ms/step - accuracy: 0.3009 - loss: 10.6548 - precision: 0.3014 - recall: 0.3008
# /usr/lib/python3.10/contextlib.py:153: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 186s 759ms/step - accuracy: 0.3031 - loss: 10.6327 - precision: 0.3036 - recall: 0.3031 - val_accuracy: 0.5241 - val_loss: 7.3094 - val_precision: 0.5241 - val_recall: 0.5236
# Epoch 2/100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.4665 - loss: 8.7857 - precision: 0.4666 - recall: 0.4665 - val_accuracy: 0.6213 - val_loss: 5.7865 - val_precision: 0.6219 - val_recall: 0.6213
# Epoch 3/100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.4941 - loss: 7.6516 - precision: 0.4943 - recall: 0.4940 - val_accuracy: 0.6038 - val_loss: 5.9522 - val_precision: 0.6043 - val_recall: 0.6038
# Epoch 4/100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.5429 - loss: 6.6841 - precision: 0.5431 - recall: 0.5428 - val_accuracy: 0.6173 - val_loss: 5.6442 - val_precision: 0.6173 - val_recall: 0.6173
# Epoch 5/100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.5646 - loss: 6.2813 - precision: 0.5647 - recall: 0.5643 - val_accuracy: 0.6592 - val_loss: 4.6047 - val_precision: 0.6596 - val_recall: 0.6587
# Epoch 6/100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - accuracy: 0.5896 - loss: 4.5596 - precision: 0.6036 - recall: 0.5760 - val_accuracy: 0.6105 - val_loss: 1.3167 - val_precision: 0.7967 - val_recall: 0.4939
# Epoch 7/100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.5105 - loss: 1.4390 - precision: 0.7257 - recall: 0.3480 - val_accuracy: 0.5434 - val_loss: 1.1643 - val_precision: 0.7799 - val_recall: 0.4259
# Epoch 8/100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 7s 32ms/step - accuracy: 0.4921 - loss: 1.2849 - precision: 0.7236 - recall: 0.3505 - val_accuracy: 0.6002 - val_loss: 1.1135 - val_precision: 0.7884 - val_recall: 0.4782
# Epoch 9/100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.5059 - loss: 1.1907 - precision: 0.7167 - recall: 0.3642 - val_accuracy: 0.5651 - val_loss: 1.1533 - val_precision: 0.7315 - val_recall: 0.4552
# Epoch 10/100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.5354 - loss: 1.1379 - precision: 0.7207 - recall: 0.4052 - val_accuracy: 0.6547 - val_loss: 1.0118 - val_precision: 0.8110 - val_recall: 0.5196
# Epoch 11/100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 7s 31ms/step - accuracy: 0.
100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step - accuracy: 0.6492 - loss: 0.8032 - precision_2: 0.7495 - recall_2: 0.5408 - val_accuracy: 0.7321 - val_loss: 0.7028 - val_precision_2: 0.8380 - val_recall_2: 0.6267
# Epoch 7/100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.6731 - loss: 0.7617 - precision_2: 0.7648 - recall_2: 0.5694 - val_accuracy: 0.6808 - val_loss: 0.7768 - val_precision_2: 0.7834 - val_recall_2: 0.5912
# Epoch 8/100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.6801 - loss: 0.7210 - precision_2: 0.7710 - recall_2: 0.5851 - val_accuracy: 0.6943 - val_loss: 0.7863 - val_precision_2: 0.7734 - val_recall_2: 0.6101
# Epoch 9/100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.6914 - loss: 0.7025 - precision_2: 0.7793 - recall_2: 0.6040 - val_accuracy: 0.7335 - val_loss: 0.7103 - val_precision_2: 0.8235 - val_recall_2: 0.6511
# Epoch 10/100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.7129 - loss: 0.6652 - precision_2: 0.7953 - recall_2: 0.6319 - val_accuracy: 0.7312 - val_loss: 0.7049 - val_precision_2: 0.8123 - val_recall_2: 0.6506
# Epoch 11/100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - accuracy: 0.7013 - loss: 0.6787 - precision_2: 0.7874 - recall_2: 0.6166 - val_accuracy: 0.7452 - val_loss: 0.6820 - val_precision_2: 0.8131 - val_recall_2: 0.6875
# Epoch 12/100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.7187 - loss: 0.6417 - precision_2: 0.7961 - recall_2: 0.6435 - val_accuracy: 0.7411 - val_loss: 0.7109 - val_precision_2: 0.8055 - val_recall_2: 0.6637
# Epoch 13/100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - accuracy: 0.7321 - loss: 0.6102 - precision_2: 0.8032 - recall_2: 0.6598 - val_accuracy: 0.7465 - val_loss: 0.6816 - val_precision_2: 0.8018 - val_recall_2: 0.6992
# Epoch 14/100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.7412 - loss: 0.5976 - precision_2: 0.8031 - recall_2: 0.6774 - val_accuracy: 0.7389 - val_loss: 0.7139 - val_precision_2: 0.8008 - val_recall_2: 0.6844
# Epoch 15/100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 8s 34ms/step - accuracy: 0.7493 - loss: 0.5713 - precision_2: 0.8139 - recall_2: 0.6833 - val_accuracy: 0.7438 - val_loss: 0.6815 - val_precision_2: 0.8094 - val_recall_2: 0.6884
# Epoch 16/100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.7622 - loss: 0.5543 - precision_2: 0.8225 - recall_2: 0.6997 - val_accuracy: 0.7028 - val_loss: 0.8196 - val_precision_2: 0.7444 - val_recall_2: 0.6583
# Epoch 17/100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.7632 - loss: 0.5565 - precision_2: 0.8195 - recall_2: 0.7039 - val_accuracy: 0.7461 - val_loss: 0.6978 - val_precision_2: 0.7933 - val_recall_2: 0.6929
# Epoch 18/100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - accuracy: 0.7682 - loss: 0.5432 - precision_2: 0.8253 - recall_2: 0.7105 - val_accuracy: 0.7366 - val_loss: 0.7254 - val_precision_2: 0.8056 - val_recall_2: 0.6902
# Epoch 19/100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 8s 35ms/step - accuracy: 0.7690 - loss: 0.5364 - precision_2: 0.8236 - recall_2: 0.7138 - val_accuracy: 0.7551 - val_loss: 0.6779 - val_precision_2: 0.8094 - val_recall_2: 0.6943
# Epoch 20/100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.7800 - loss: 0.5119 - precision_2: 0.8361 - recall_2: 0.7288 - val_accuracy: 0.7533 - val_loss: 0.6893 - val_precision_2: 0.7980 - val_recall_2: 0.7024
# Epoch 21/100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.7880 - loss: 0.4907 - precision_2: 0.8414 - recall_2: 0.7377 - val_accuracy: 0.7474 - val_loss: 0.7195 - val_precision_2: 0.7998 - val_recall_2: 0.6979
# Epoch 22/100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.7958 - loss: 0.4762 - precision_2: 0.8479 - recall_2: 0.7466 - val_accuracy: 0.7276 - val_loss: 0.7553 - val_precision_2: 0.7918 - val_recall_2: 0.6695
# Epoch 23/100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.7971 - loss: 0.4635 - precision_2: 0.8491 - recall_2: 0.7505 - val_accuracy: 0.7407 - val_loss: 0.7506 - val_precision_2: 0.7788 - val_recall_2: 0.7037
# Epoch 24/100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.7987 - loss: 0.4719 - precision_2: 0.8469 - recall_2: 0.7546 - val_accuracy: 0.7276 - val_loss: 0.8009 - val_precision_2: 0.7796 - val_recall_2: 0.6943
# Epoch 25/100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.7770 - loss: 0.4977 - precision_2: 0.8316 - recall_2: 0.7320 - val_accuracy: 0.7609 - val_loss: 0.7360 - val_precision_2: 0.7989 - val_recall_2: 0.7208
# Epoch 26/100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.8089 - loss: 0.4466 - precision_2: 0.8543 - recall_2: 0.7701 - val_accuracy: 0.7506 - val_loss: 0.7663 - val_precision_2: 0.7961 - val_recall_2: 0.7172
# Epoch 27/100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.8161 - loss: 0.4317 - precision_2: 0.8574 - recall_2: 0.7755 - val_accuracy: 0.7533 - val_loss: 0.7185 - val_precision_2: 0.7980 - val_recall_2: 0.7114
# Epoch 28/100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.8089 - loss: 0.4385 - precision_2: 0.8518 - recall_2: 0.7724 - val_accuracy: 0.7582 - val_loss: 0.7727 - val_precision_2: 0.7872 - val_recall_2: 0.7330
# Epoch 29/100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - accuracy: 0.8284 - loss: 0.4042 - precision_2: 0.8677 - recall_2: 0.7931 - val_accuracy: 0.7276 - val_loss: 0.8555 - val_precision_2: 0.7667 - val_recall_2: 0.6925
# Evaluating EfficientNetB0 on validation set:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 178ms/step - accuracy: 0.7674 - loss: 0.6590 - precision_2: 0.8153 - recall_2: 0.7026
# Genearting predictions for EfficientNetB0 on validation set:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 8s/step
# Training MobileNetV3Small...
# /usr/local/lib/python3.10/dist-packages/keras/src/applications/mobilenet_v3.py:452: UserWarning: `input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.
#   return MobileNetV3(
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v3/weights_mobilenet_v3_small_224_1.0_float_no_top_v2.h5
# 4334752/4334752 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Epoch 1/100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 57s 191ms/step - accuracy: 0.2575 - loss: 6.0801 - precision_3: 0.2556 - recall_3: 0.1703 - val_accuracy: 0.6623 - val_loss: 1.0373 - val_precision_3: 0.8663 - val_recall_3: 0.4057
# Epoch 2/100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.5110 - loss: 1.1707 - precision_3: 0.6687 - recall_3: 0.3048 - val_accuracy: 0.6758 - val_loss: 0.9501 - val_precision_3: 0.8601 - val_recall_3: 0.4624
# Epoch 3/100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.5327 - loss: 1.0889 - precision_3: 0.6789 - recall_3: 0.3571 - val_accuracy: 0.5741 - val_loss: 1.0343 - val_precision_3: 0.7186 - val_recall_3: 0.4322
# Epoch 4/100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.5626 - loss: 1.0277 - precision_3: 0.6914 - recall_3: 0.3953 - val_accuracy: 0.6889 - val_loss: 0.8629 - val_precision_3: 0.8082 - val_recall_3: 0.5673
# Epoch 5/100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - accuracy: 0.6144 - loss: 0.9201 - precision_3: 0.7234 - recall_3: 0.4674 - val_accuracy: 0.7132 - val_loss: 0.7564 - val_precision_3: 0.8067 - val_recall_3: 0.6218
# Epoch 6/100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.6147 - loss: 0.9069 - precision_3: 0.7221 - recall_3: 0.4771 - val_accuracy: 0.7033 - val_loss: 0.8217 - val_precision_3: 0.8370 - val_recall_3: 0.5664
# Epoch 7/100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.6389 - loss: 0.8556 - precision_3: 0.7569 - recall_3: 0.5105 - val_accuracy: 0.6763 - val_loss: 0.8303 - val_precision_3: 0.7829 - val_recall_3: 0.5682
# Epoch 8/100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.6438 - loss: 0.8296 - precision_3: 0.7520 - recall_3: 0.5206 - val_accuracy: 0.7299 - val_loss: 0.7404 - val_precision_3: 0.8135 - val_recall_3: 0.6578
# Epoch 9/100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.6687 - loss: 0.7700 - precision_3: 0.7690 - recall_3: 0.5562 - val_accuracy: 0.7226 - val_loss: 0.7987 - val_precision_3: 0.8210 - val_recall_3: 0.6173
# Epoch 10/100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.6793 - loss: 0.7480 - precision_3: 0.7772 - recall_3: 0.5714 - val_accuracy: 0.7335 - val_loss: 0.7682 - val_precision_3: 0.8173 - val_recall_3: 0.6425
# Epoch 11/100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 7s 30ms/step - accuracy: 0.6928 - loss: 0.7088 - precision_3: 0.7832 - recall_3: 0.5957 - val_accuracy: 0.7429 - val_loss: 0.7345 - val_precision_3: 0.8221 - val_recall_3: 0.6493
# Epoch 12/100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.7009 - loss: 0.6995 - precision_3: 0.7889 - recall_3: 0.5977 - val_accuracy: 0.7438 - val_loss: 0.7602 - val_precision_3: 0.8118 - val_recall_3: 0.6700
# Epoch 13/100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.7083 - loss: 0.6913 - precision_3: 0.7864 - recall_3: 0.6135 - val_accuracy: 0.7159 - val_loss: 0.8169 - val_precision_3: 0.8009 - val_recall_3: 0.6267
# Epoch 14/100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - accuracy: 0.7142 - loss: 0.6698 - precision_3: 0.7949 - recall_3: 0.6250 - val_accuracy: 0.7456 - val_loss: 0.7221 - val_precision_3: 0.8090 - val_recall_3: 0.6902
# Epoch 15/100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 7s 29ms/step - accuracy: 0.7315 - loss: 0.6212 - precision_3: 0.8079 - recall_3: 0.6514 - val_accuracy: 0.7650 - val_loss: 0.7012 - val_precision_3: 0.8216 - val_recall_3: 0.7028
# Epoch 16/100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.7399 - loss: 0.6134 - precision_3: 0.8189 - recall_3: 0.6596 - val_accuracy: 0.7515 - val_loss: 0.7287 - val_precision_3: 0.8041 - val_recall_3: 0.7042
# Epoch 17/100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.7424 - loss: 0.5909 - precision_3: 0.8202 - recall_3: 0.6636 - val_accuracy: 0.6965 - val_loss: 0.9298 - val_precision_3: 0.7562 - val_recall_3: 0.6060
# Epoch 18/100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.7478 - loss: 0.5898 - precision_3: 0.8177 - recall_3: 0.6717 - val_accuracy: 0.7465 - val_loss: 0.7766 - val_precision_3: 0.8042 - val_recall_3: 0.6952
# Epoch 19/100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - accuracy: 0.7559 - loss: 0.5565 - precision_3: 0.8214 - recall_3: 0.6853 - val_accuracy: 0.7479 - val_loss: 0.7781 - val_precision_3: 0.7999 - val_recall_3: 0.7001
# Epoch 20/100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.7667 - loss: 0.5444 - precision_3: 0.8303 - recall_3: 0.6923 - val_accuracy: 0.7614 - val_loss: 0.7168 - val_precision_3: 0.8185 - val_recall_3: 0.7064
# Epoch 21/100
# 234/234 ━━━━━━━━━━━━━━━━━━━━ 5s 21ms/step - accuracy: 0.

# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 176ms/step - accuracy: 0.7803 - loss: 0.6358 - precision_4: 0.8226 - recall_4: 0.7281
# Genearting predictions for EfficientNetV2B0 on validation set:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step

# %% [markdown]
# ## ROC Curve

# %%
import numpy as np
from sklearn.metrics import confusion_matrix, roc_curve, auc
from sklearn.preprocessing import label_binarize
import matplotlib.pyplot as plt

# Function to plot the ROC curve
def plot_roc_curve(y_true, y_pred_prob, class_names, model_name):
    # One-hot encode the true labels
    y_true_one_hot = label_binarize(y_true, classes=range(len(class_names)))

    classes_map = {
        'asch':'ASC-H',
        'ascus':'ASC-US',
        'hsil':'HSIL',
        'lsil':'LSIL',
        'normal':'NILM',
        'scc':'SCC',
    }

    fpr = {}
    tpr = {}
    roc_auc = {}

    plt.figure()
    for i in range(len(class_names)):
        fpr[i], tpr[i], _ = roc_curve(y_true_one_hot[:, i], y_pred_prob[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])
        plt.plot(fpr[i], tpr[i], label=f'{classes_map[class_names[i]]} (area = {roc_auc[i]:.2f})')

    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('Taxa de falsos positivos')
    plt.ylabel('Taxa de verdadeiros positivos')
    plt.title(f'Curva ROC ({model_name})')
    plt.legend(loc='lower right')
    plt.show()

# %%
# # Example: Generate confusion matrix and ROC curve for one model (e.g., VGG16)
# y_true = []  # Store true labels
# y_pred = []  # Store predicted labels
# y_pred_prob = []  # Store predicted probabilities for ROC curve

# # Get predictions from the trained model
# for images, labels in val_dataset:
#     preds = model.predict(images)
#     y_true.append(np.argmax(labels, axis=1))
#     y_pred.append(np.argmax(preds, axis=1))
#     y_pred_prob.append(preds)

# # Convert lists to numpy arrays
# y_true = np.concatenate(y_true)
# y_pred = np.concatenate(y_pred)
# y_pred_prob = np.concatenate(y_pred_prob)

# Plot the ROC curve
for model_name, results in model_results.items():
  y_true = results['y_true']
  y_pred_prob = results['y_pred_prob']
  plot_roc_curve(y_true, y_pred_prob, dataset.class_names, model_name)

# %% [markdown]
# # Metrics extraction

# %% [markdown]
# ## Confusion Matrix

# %%
# Matriz de confusão

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Function to plot the confusion matrix
def plot_confusion_matrix(y_true, y_pred, class_names, model_name):
    cm = confusion_matrix(y_true, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
    disp.plot(cmap=plt.cm.Blues)
    plt.title(f'Confusion Matrix for {model_name}')
    plt.show()

# Example: Generate confusion matrix for one model
# y_pred = []  # Store predicted labels

# # Get predictions from the trained model
# for images, labels in val_dataset:
#     preds = model.predict(images)
#     y_pred.append(np.argmax(preds, axis=1))

# # Convert lists to numpy arrays
# y_pred = np.concatenate(y_pred)

# model_list = {
#     'VGG16': VGG16,
#     'ResNet50': ResNet50,
#     'EfficientNetB0': EfficientNetB0,
#     'InceptionV3': InceptionV3,
#     'MobileNetV3Small': MobileNetV3Small,
#     'EfficientNetV2B0': EfficientNetV2B0
# }

# Plot the confusion matrix
for model_name, results in model_results.items():
  y_true = results['y_true']
  y_pred = results['y_pred']
  plot_confusion_matrix(y_true, y_pred, class_names=dataset.class_names, model_name=model_name)

# %% [markdown]
# ## Accuracy and loss curves

# %%
# Curva de perda e acurácia

# Function to plot loss and accuracy curves
def plot_loss_accuracy(history, model_name):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(1, len(acc) + 1)

    # Plot accuracy
    plt.figure()
    plt.plot(epochs, acc, 'bo-', label='Training accuracy')
    plt.plot(epochs, val_acc, 'r*-', label='Validation accuracy')
    plt.title(f'Training and Validation Accuracy for {model_name}')
    plt.legend()
    plt.show()

    # Plot loss
    plt.figure()
    plt.plot(epochs, loss, 'bo-', label='Training loss')
    plt.plot(epochs, val_loss, 'r*-', label='Validation loss')
    plt.title(f'Training and Validation Loss for {model_name}')
    plt.legend()
    plt.show()

# model_list = {
#     'VGG16': VGG16,
#     'ResNet50': ResNet50,
#     'EfficientNetB0': EfficientNetB0,
#     'InceptionV3': InceptionV3,
#     'MobileNetV3Small': MobileNetV3Small,
#     'EfficientNetV2B0': EfficientNetV2B0
# }

# Example: Plot loss and accuracy for one model

for model_name, results in model_results.items():
  history = results['history']
  plot_loss_accuracy(history, model_name)

# %% [markdown]
# ## Additional metrics

# %%
for model_name, results in model_results.items():
  y_true = results['y_true']
  y_pred = results['y_pred']

  # Calculate precision, recall, F1 score
  print(f"Classification Report for {model_name}:")
  print(classification_report(y_true, y_pred, target_names=dataset.class_names))

  # Calculate F1 Score
  f1 = f1_score(y_true, y_pred, average='weighted')  # Weighted F1 for multiclass
  print(f"Weighted F1 Score for {model_name}: {f1:.4f}")
# Out:
# Classification Report for VGG16:
#               precision    recall  f1-score   support
#
#         asch       0.35      0.77      0.48       175
#        ascus       0.26      0.53      0.35       110
#         hsil       0.84      0.55      0.67       353
#         lsil       0.53      0.22      0.31       283
#       normal       0.90      0.87      0.88      1269
#          scc       0.37      0.48      0.42        31
#
#     accuracy                           0.70      2221
#    macro avg       0.54      0.57      0.52      2221
# weighted avg       0.76      0.70      0.71      2221
#
# Weighted F1 Score for VGG16: 0.7111
# Classification Report for ResNet50:
#               precision    recall  f1-score   support
#
#         asch       0.21      0.78      0.33       175
#        ascus       0.33      0.15      0.21       110
#         hsil       0.00      0.00      0.00       353
#         lsil       0.00      0.00      0.00       283
#       normal       0.76      0.90      0.82      1269
#          scc       0.00      0.00      0.00        31
#
#     accuracy                           0.58      2221
#    macro avg       0.22      0.31      0.23      2221
# weighted avg       0.46      0.58      0.51      2221
#
# Weighted F1 Score for ResNet50: 0.5053
# Classification Report for EfficientNetB0:
#               precision    recall  f1-score   support
#
#         asch       0.51      0.62      0.56       175
#        ascus       0.33      0.53      0.41       110
#         hsil       0.82      0.70      0.75       353
#         lsil       0.57      0.39      0.47       283
#       normal       0.88      0.89      0.88      1269
#          scc       0.44      0.58      0.50        31
#
#     accuracy                           0.76      2221
#    macro avg       0.59      0.62      0.60      2221
# weighted avg       0.77      0.76      0.76      2221
#
# Weighted F1 Score for EfficientNetB0: 0.7558
# Classification Report for MobileNetV3Small:
#               precision    recall  f1-score   support
#
#         asch       0.56      0.54      0.55       175
#        ascus       0.40      0.41      0.41       110
#         hsil       0.76      0.74      0.75       353
#         lsil       0.56      0.51      0.53       283
#       normal       0.89      0.89      0.89      1269
#          scc       0.34      0.65      0.45        31
#
#     accuracy                           0.76      2221
#    macro avg       0.58      0.62      0.60      2221
# weighted avg       0.77      0.76      0.77      2221
#
# Weighted F1 Score for MobileNetV3Small: 0.7650
# Classification Report for EfficientNetV2B0:
#               precision    recall  f1-score   support
#
#         asch       0.42      0.72      0.53       175
#        ascus       0.41      0.47      0.44       110
#         hsil       0.79      0.75      0.77       353
#         lsil       0.71      0.39      0.50       283
#       normal       0.89      0.90      0.90      1269
#          scc       0.52      0.48      0.50        31
#
#     accuracy                           0.77      2221
#    macro avg       0.62      0.62      0.61      2221
# weighted avg       0.79      0.77      0.77      2221
#
# Weighted F1 Score for EfficientNetV2B0: 0.7698
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
